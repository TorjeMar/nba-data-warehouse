# %%
# %load_ext autoreload
# %autoreload 2
# %cd /home/abraham/uni/ikt453/project/v1
# Out:
# /home/abraham/uni/ikt453/project/v1

# %%
from collections import defaultdict
from copy import deepcopy
from uuid import uuid4

from src.utils import disk
from src.utils import debug

# %%
players = 'data/players_v2/data'
players = disk.listdir(players)
players = map(lambda x: disk.joinpath(x, 'parsed.json'), players)
players = list(players)

# %%
sample = disk.read_json(players[0])

# %%
len(sample)
# Out:
# 1

# %%
# Page with players has key players under pageProps
# Page with single player has key player under pageProps

len(sample[0]['data']['props']['pageProps']['players'])
# Out:
# 588

# %%
nba_players = disk.read_json('data/figure_out/nba_players.json')

# %%
len(nba_players['props']['pageProps']['players'])
# Out:
# 588

# %%
players[2]
# Out:
# 'data/players_v2/data/705/parsed.json'
