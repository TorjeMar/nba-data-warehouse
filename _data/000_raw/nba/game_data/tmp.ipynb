# %%
# %load_ext autoreload
# %autoreload 2
# %cd /home/abraham/uni/ikt453/project/v1
# Out:
# /home/abraham/uni/ikt453/project/v1

# %%
from _v2.utils.provenance import build_provenance_envelope

# %%
from tqdm import tqdm
from src.utils import disk
path = '_data/000_raw/nba/game_data/data'
files = disk.listdir(path)
len(files)

# for file in tqdm(files):
#     path = disk.joinpath(file, 'parsed.json')
#     if not disk.isfile(path):
#         print(f'File {path} does not exist, skipping.')
#         continue

#     data = disk.read_json(path)

#     keys = (
#         'is_directory_input',
#         'is_directory_output',
#         'timestamp',
#         'input_data',
#         'processing',

#     )

#     if all(key in data for key in keys):
#         continue

#     envelope = build_provenance_envelope(
#         data=data,
#         source='nba',
#         path_input_data=None,
#         path_processing_script='_data/000_raw/nba/game_data/download.py',
#         is_directory_input=False,
#         is_directory_output=False,
#     )

#     disk.write_json(path, envelope)
# Out:
# 18246
